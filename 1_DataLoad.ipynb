# %%
import os
import tarfile
from six.moves import urllib

# DOWNLOAD_ROOT = 'https://raw.githubusercontent.com/ageron/handson-ml/master/'
DOWNLOAD_ROOT = 'https://github.com/ageron/handson-ml/tree/master/'
HOUSING_PATH = 'datasets/housing'
HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + "/housing.tgz"

# print(HOUSING_URL)
if not os.path.isdir(HOUSING_PATH):
    os.makedirs(HOUSING_PATH)
tgz_path = os.path.join(HOUSING_PATH, "housing.tgz")
tgz_path = "./" + HOUSING_PATH + "/housing.tgz"
print(tgz_path)
urllib.request.urlretrieve(HOUSING_URL, tgz_path)
housing_tgz = tarfile.open(tgz_path)
housing_tgz.extractall(path = HOUSING_PATH)
housing_tgz.close()
# Out:
# ./datasets/housing/housing.tgz
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# <ipython-input-14-e67294c876ae> in <module>
#      15 print(tgz_path)
#      16 urllib.request.urlretrieve(HOUSING_URL, tgz_path)
# ---> 17 housing_tgz = tarfile.open(tgz_path)
#      18 housing_tgz.extractall(path = HOUSING_PATH)
#      19 housing_tgz.close()
#
# ~\anaconda3\lib\tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1604                         fileobj.seek(saved_pos)
#    1605                     continue
# -> 1606             raise ReadError("file could not be opened successfully")
#    1607
#    1608         elif ":" in mode:
#
# ReadError: file could not be opened successfully

# %%
from requests import get  # to make GET request

DOWNLOAD_ROOT = 'https://github.com/ageron/handson-ml/tree/master/'
HOUSING_PATH = 'datasets/housing'
# HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + "/housing.tgz"
HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + "/housing.csv"

def download(url, file_name):
    with open(file_name, "wb") as file:   # open in binary mode
        response = get(url)               # get request
        file.write(response.content)      # write to file

url = "http://wasabisyrup.com/storage/gallery/-quJruo2cWQ/m0071_6lMClr7aldA.jpg"
url = HOUSING_URL
# download(url,"./datasets/housing/housing2.tgz
download(url,"./datasets/housing/housing2.csv")

# %%
from urllib import request

DOWNLOAD_ROOT = 'https://github.com/ageron/handson-ml/tree/master/'
HOUSING_PATH = 'datasets/housing'
# HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + "/housing.tgz"
HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + "/housing.csv"

url = "http://cfs4.tistory.com/upload_control/download.blog?fhandle=YmxvZzEyNDM3NEBmczQudGlzdG9yeS5jb206L2F0dGFjaC8wLzA5MDAwMDAwMDAwMC5qcGc%3D" 
url = HOUSING_URL
# savename = "./datasets/housing/housing3.tgz"
savename = "./datasets/housing/housing3.csv"
request.urlretrieve(url,savename) 
print("저장되었습니다.")
# Out:
# 저장되었습니다.

# %%
import pandas as pd
csv_path = './datasets/housing/housing.csv'
pdhousing = pd.read_csv(csv_path)
# header 없다면 header=None
# sep : str, default ‘,’
# encoding : 'utf-8', 'cp949'

# %%
pdhousing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...
